# %%
import tweepy
import csv
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np 
import re
import matplotlib.pyplot as plt
import sklearn
plt.style.use('fivethirtyeight')

# %%
file = open(r'C:\Keziah\Ukraine Tweets\filename.csv', encoding="utf8")

# %%
csvreader = csv.reader(file)

# %%
header = []
header = next(csvreader)
header
# Out:
# ['id',
#  'conversation_id',
#  'created_at',
#  'date',
#  'time',
#  'timezone',
#  'user_id',
#  'username',
#  'name',
#  'place',
#  'tweet',
#  'language',
#  'mentions',
#  'urls',
#  'photos',
#  'replies_count',
#  'retweets_count',
#  'likes_count',
#  'hashtags',
#  'cashtags',
#  'link',
#  'retweet',
#  'quote_url',
#  'video',
#  'thumbnail',
#  'near',
#  'geo',
#  'source',
#  'user_rt_id',
#  'user_rt',
#  'retweet_id',
#  'reply_to',
#  'retweet_date',
#  'translate',
#  'trans_src',
#  'trans_dest']

# %%
rows = []
for row in csvreader:
        rows.append(row)
rows
# Out:
# [['1502525606596169728',
#   '1502257690394963971',
#   '2022-03-12 06:03:14 UTC',
#   '2022-03-12',
#   '06:03:14',
#   '+0000',
#   '20198797',
#   'redcelia',
#   'Johnson Out🇺🇦 🇪🇺🇮🇹🇦🇫💙😷 #NeverVoteTory',
#   '',
#   '@RussianEmbassy @FT @mfa_russia @JeffDSachs @CSD_Columbia @RusEmbUSA @ftworldnews @natomission_ru @RusembUkraine @REESOxford @WRForum @BBCWorld Prove that you are not a threat by pulling out of Ukraine and stopping the murder of civilians in the country. Ukraine has every right to fight for its independence from your bloodthirsty regime and every right to join whatever alliance it wants. #StandWithUkraine #PutinWarCrimes',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['standwithukraine', 'putinwarcrimes']",
#   '[]',
#   'https://twitter.com/redcelia/status/1502525606596169728',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[{\'screen_name\': \'RussianEmbassy\', \'name\': \'Russian Embassy, UK\', \'id\': \'114718372\'}, {\'screen_name\': \'FT\', \'name\': \'Financial Times\', \'id\': \'18949452\'}, {\'screen_name\': \'mfa_russia\', \'name\': \'MFA Russia 🇷🇺\', \'id\': \'255471924\'}, {\'screen_name\': \'JeffDSachs\', \'name\': \'Jeffrey D. Sachs\', \'id\': \'116763916\'}, {\'screen_name\': \'CSD_Columbia\', \'name\': \'CSD Columbia\', \'id\': \'777984179225100290\'}, {\'screen_name\': \'RusEmbUSA\', \'name\': \'Russian Embassy in USA 🇷🇺\', \'id\': \'1267887043\'}, {\'screen_name\': \'ftworldnews\', \'name\': \'FT World News\', \'id\': \'312677640\'}, {\'screen_name\': \'natomission_ru\', \'name\': \'Russia and NATO\', \'id\': \'187874400\'}, {\'screen_name\': \'RusembUkraine\', \'name\': \'RusEmbassy Ukraine\', \'id\': \'1256490685\'}, {\'screen_name\': \'REESOxford\', \'name\': \'Oxford University Russian & East European Studies\', \'id\': \'1856942821\'}, {\'screen_name\': \'WRForum\', \'name\': "W\'minsterRussiaForum", \'id\': \'600036277\'}, {\'screen_name\': \'BBCWorld\', \'name\': \'BBC News (World)\', \'id\': \'742143\'}]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525604536541191',
#   '1502525604536541191',
#   '2022-03-12 06:03:14 UTC',
#   '2022-03-12',
#   '06:03:14',
#   '+0000',
#   '227535569',
#   'eee_eff',
#   'Wearing Masks still saves lives 🇺🇦🇲🇨🏥🌹🌹',
#   '',
#   "Kidnapped, without any charges or access to a lawyer. This is what Putin's Russia is, criminality of the state without any accountability.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/eee_eff/status/1502525604536541191',
#   'False',
#   'https://twitter.com/CNN/status/1502369337629413380',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525600917082112',
#   '1502525600917082112',
#   '2022-03-12 06:03:13 UTC',
#   '2022-03-12',
#   '06:03:13',
#   '+0000',
#   '84313171',
#   'mistify_007',
#   'Brian🤸\u200d♀️',
#   '',
#   "So much for western civilization, everyone feels so compelled to find a creative way to punish Russia and her people who don't even support this war.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/mistify_007/status/1502525600917082112',
#   'False',
#   'https://twitter.com/JamesMelville/status/1502416955000737794',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525598282960898',
#   '1502214676561776642',
#   '2022-03-12 06:03:12 UTC',
#   '2022-03-12',
#   '06:03:12',
#   '+0000',
#   '989861790245900289',
#   'reallivinghuman',
#   'Basha',
#   '',
#   "@RussianEmbassy Lovely place, I'll visit it for sure in my next trip to Russia along with Kaliningrad and Donbass. Long live Russia 🇷🇺 🙏",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/reallivinghuman/status/1502525598282960898',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'RussianEmbassy', 'name': 'Russian Embassy, UK', 'id': '114718372'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525596898836480',
#   '1500436651264380931',
#   '2022-03-12 06:03:12 UTC',
#   '2022-03-12',
#   '06:03:12',
#   '+0000',
#   '1164944946392109056',
#   'rpcsas',
#   'RonJon',
#   '',
#   "@IsraeliPM @iaeaorg Didn't know the state of Israel advised the oppressed, especially their Jewish brethren in Ukraine to surrender to the Nazis of Russia!  https://t.co/Ygt2yc23UI",
#   'en',
#   '[]',
#   "['https://twitter.com/SykesCharlie/status/1502444652053639169?s=20&t=O_0mdOM_CqtpKhqDWb23lQ']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/rpcsas/status/1502525596898836480',
#   'False',
#   'https://twitter.com/SykesCharlie/status/1502444652053639169?s=20&t=O_0mdOM_CqtpKhqDWb23lQ',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'IsraeliPM', 'name': 'Prime Minister of Israel', 'id': '141084952'}, {'screen_name': 'iaeaorg', 'name': 'IAEA - International Atomic Energy Agency', 'id': '19386622'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525592868114432',
#   '1502423816898818058',
#   '2022-03-12 06:03:11 UTC',
#   '2022-03-12',
#   '06:03:11',
#   '+0000',
#   '301697265',
#   'pjchidolue',
#   'PJ 🇳🇬',
#   '',
#   '@nexta_tv They are attacking Russia in every way they know how. This can never backfire.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/pjchidolue/status/1502525592868114432',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'nexta_tv', 'name': 'NEXTA', 'id': '1891490382'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525590330564611',
#   '1502075252989382664',
#   '2022-03-12 06:03:10 UTC',
#   '2022-03-12',
#   '06:03:10',
#   '+0000',
#   '1210205111705833472',
#   'odeca8',
#   'Ekurul',
#   '',
#   "@EnvyRonman @WhatMeDiZany @DubiousRoux @Killa_ru I wasn't aware we invaded Lybia. i must have been a sleep.  I think you are not aware of the past 30 years of wars of Russia, are you? Also, do you really want to compare IRAQ, where there one of the wrost dictator of the past 50 years? Do you even know who Hussein was? Fuck sake",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Odeca8/status/1502525590330564611',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'EnvyRonman', 'name': 'Envy Ronman', 'id': '1495797891281170440'}, {'screen_name': 'WhatMeDiZany', 'name': 'DiZany ►DQ♩', 'id': '23668686'}, {'screen_name': 'DubiousRoux', 'name': 'Riaan Roux', 'id': '1639695770'}, {'screen_name': 'Killa_ru', 'name': 'Igor Baikov 💙💛', 'id': '286063554'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525589739249667',
#   '1502463011797229568',
#   '2022-03-12 06:03:10 UTC',
#   '2022-03-12',
#   '06:03:10',
#   '+0000',
#   '2762575768',
#   'cdw82592',
#   'Cody Warner',
#   '',
#   '@Ross_Beasley Actually it’s a big part of it joe along with your idiotic reasons to do everything that goes against using common sense such as shutting down every important pipeline project within the USA or buying your oil from Russia and the Middle East, shall I continue….',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/cdw82592/status/1502525589739249667',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'Ross_Beasley', 'name': 'Ross Beasley', 'id': '69691904'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525588006916097',
#   '1502525588006916097',
#   '2022-03-12 06:03:10 UTC',
#   '2022-03-12',
#   '06:03:10',
#   '+0000',
#   '721080969759952896',
#   'unitloaded',
#   'unitloaded',
#   '',
#   'The Ukrainian FA Have Severely Punished Anatoliy Tymoshchuk After He Failed To Condemn Russia, And Continues To Work For Zenit St\xa0Petersburg  https://t.co/x2NDXbuipf',
#   'en',
#   '[]',
#   "['https://legitwap.com.ng/the-ukrainian-fa-have-severely-punished-anatoliy-tymoshchuk-after-he-failed-to-condemn-russia-and-continues-to-work-for-zenit-st-petersburg/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/unitloaded/status/1502525588006916097',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525585469362178',
#   '1502326991395205127',
#   '2022-03-12 06:03:09 UTC',
#   '2022-03-12',
#   '06:03:09',
#   '+0000',
#   '1383812395542274055',
#   'cosmoeos',
#   'Cosmo Eos',
#   '',
#   "@tomerabramov2 @yarotrof @ILAerospaceIAI @TimesofIsrael @IsraelMFA @IDF Not at all as I see it. This is about your gov not doing what they should and can. @IsraeliPM's suggestion to Zelensky to surrender to Russia and accept Putin's insane demands were beyond shocking. It would be like the US or EU to urge Israel to surrender to those that attack u.",
#   'en',
#   "[{'screen_name': 'israelipm', 'name': 'prime minister of israel', 'id': '141084952'}]",
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/CosmoEos/status/1502525585469362178',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'tomerabramov2', 'name': 'tomer abramov', 'id': '1485197352440844290'}, {'screen_name': 'yarotrof', 'name': 'Yaroslav Trofimov', 'id': '30011100'}, {'screen_name': 'ILAerospaceIAI', 'name': 'Israel Aerospace Industries', 'id': '4307228609'}, {'screen_name': 'TimesofIsrael', 'name': 'The Times of Israel', 'id': '432557320'}, {'screen_name': 'IsraelMFA', 'name': 'Israel Foreign Ministry', 'id': '85796380'}, {'screen_name': 'IDF', 'name': 'Israel Defense Forces', 'id': '18576537'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525581941956609',
#   '1502525581941956609',
#   '2022-03-12 06:03:08 UTC',
#   '2022-03-12',
#   '06:03:08',
#   '+0000',
#   '1374529934278893572',
#   'mass_blog_',
#   'Mass Blog',
#   '',
#   "Macron: Russia's attack on Ukraine will 'deeply destabilise' food supplies in\xa0Europe  https://t.co/TN8uvSW7yP",
#   'en',
#   '[]',
#   "['https://www.massblog.xyz/macron-russias-attack-on-ukraine-will-deeply-destabilise-food-supplies-in-europe/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/mass_blog_/status/1502525581941956609',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525581346238464',
#   '1502425551918751745',
#   '2022-03-12 06:03:08 UTC',
#   '2022-03-12',
#   '06:03:08',
#   '+0000',
#   '455947303',
#   'oddinsights_tcs',
#   'Da’ Chris Smitty ⚡️🔔',
#   '',
#   '@AdamKinzinger @POTUS Unless they know there is a real reason to suspect Russia may try and provoke NATO. Then this is necessary cover.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/oddinsights_tcs/status/1502525581346238464',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'AdamKinzinger', 'name': 'Adam Kinzinger', 'id': '18004222'}, {'screen_name': 'POTUS', 'name': 'President Biden', 'id': '1349149096909668363'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525580834746368',
#   '1502520560814858240',
#   '2022-03-12 06:03:08 UTC',
#   '2022-03-12',
#   '06:03:08',
#   '+0000',
#   '1496718256144629760',
#   'marcosmilep',
#   'Marco',
#   '',
#   '@GirkinGirkin Also because of captured &amp; defect 🇷🇺 soldiers they bring Syrian soldiers. ❌ Try to promote better payment to syrian soldiers TO defect  (become prisoners of 🇺🇦) 1. NATO will pay the money 2. Russia loses soldiers 3. Syrian stay alive or join 🇺🇦 Legion Save 🇺🇦 soldiers',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/MarcoSmileP/status/1502525580834746368',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'GirkinGirkin', 'name': 'IgorGirkin', 'id': '2592557856'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525578737762304',
#   '1502523473834528770',
#   '2022-03-12 06:03:08 UTC',
#   '2022-03-12',
#   '06:03:08',
#   '+0000',
#   '1388098883855667200',
#   'hulo_1',
#   'Comrade hulo',
#   '',
#   '@visegrad24 Syrian soldiers fighting for Assad is also going to fight for Russia in Ukraine, yesterday Putin approved of this',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/hulo_1/status/1502525578737762304',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'visegrad24', 'name': 'Visegrád 24', 'id': '1222773302441148416'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525574342123524',
#   '1502525574342123524',
#   '2022-03-12 06:03:07 UTC',
#   '2022-03-12',
#   '06:03:07',
#   '+0000',
#   '975650782346448898',
#   'narrowpeak',
#   'Calmwhale',
#   '',
#   "World's best sniper ‘Wali' joins Ukraine's fight against Russia  https://t.co/UCItI0usi7 So this man is there to put fear in the Russians? What a laugh to think one man can defeat the Russian army. Propaganda at work here",
#   'en',
#   '[]',
#   "['http://a.msn.com/01/en-in/AAUXFXu?ocid=st']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/narrowpeak/status/1502525574342123524',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525573217804290',
#   '1502340352480624660',
#   '2022-03-12 06:03:06 UTC',
#   '2022-03-12',
#   '06:03:06',
#   '+0000',
#   '739193293762899968',
#   'idkuser94',
#   'Idkwhatname',
#   '',
#   '@randjelovic81 @EndGundam @JackPosobiec No the fuck they aren’t. The US didn’t tell Russia to invade Ukraine. Russia has been invading and annexing Eastern European nations for 30 years now. Which is why they lean towards NATO.  Putin apologists are ignorant.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/idkuser94/status/1502525573217804290',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'randjelovic81', 'name': 'Miljan Randjelovic', 'id': '1473646915136933894'}, {'screen_name': 'EndGundam', 'name': 'Ravkeen', 'id': '1093695260067270661'}, {'screen_name': 'JackPosobiec', 'name': 'Jack Posobiec 🇺🇸', 'id': '592730371'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525572936724480',
#   '1502525572936724480',
#   '2022-03-12 06:03:06 UTC',
#   '2022-03-12',
#   '06:03:06',
#   '+0000',
#   '1101664837145260032',
#   'rmax1dk8hudoyqq',
#   'まこと',
#   '',
#   'キエフのライブカメラ、平穏な映像です Live look at Kyiv as Russia invades Ukraine  https://t.co/lGXzrBBfjB @YouTubeより',
#   'ja',
#   "[{'screen_name': 'youtube', 'name': 'youtube', 'id': '10228272'}]",
#   "['https://youtu.be/od78OZa2FtA']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Rmax1dK8HUDOyqq/status/1502525572936724480',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525571284312065',
#   '1502525571284312065',
#   '2022-03-12 06:03:06 UTC',
#   '2022-03-12',
#   '06:03:06',
#   '+0000',
#   '1470904082089091073',
#   'stopvladdydaddy',
#   'OperationX 🇺🇦 | #StandWithUkraine',
#   '',
#   "Russia VS Ukraine.. It is horrible. I made a discord server (also in bio) to talk about it. Send your videos, images etc. Invite:  https://t.co/Ld7jko0ft3 - Let's show our support for Ukraine! #PrayForUkraine #RussiaUkraine #SaveUkraine #StopPutin #russianinvasion (21055)",
#   'en',
#   '[]',
#   "['https://discord.gg/V27CcPs9Wu']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['prayforukraine', 'russiaukraine', 'saveukraine', 'stopputin', 'russianinvasion']",
#   '[]',
#   'https://twitter.com/StopVladdyDaddy/status/1502525571284312065',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525570269290496',
#   '1502340261569077250',
#   '2022-03-12 06:03:06 UTC',
#   '2022-03-12',
#   '06:03:06',
#   '+0000',
#   '1271296787194753024',
#   'uzomam1',
#   'Uzoma',
#   '',
#   '@bunmiiee @SaharaReporters Absolutely right👍🏾The west controls the war narratives, even the sanctions they imposed on Russia will also affect and almost cripple Europe 😂😂',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Uzomam1/status/1502525570269290496',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'bunmiiee', 'name': 'Bunmi.', 'id': '1360461129760260102'}, {'screen_name': 'SaharaReporters', 'name': 'Sahara Reporters', 'id': '17409452'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525569178959874',
#   '1502512207455670281',
#   '2022-03-12 06:03:05 UTC',
#   '2022-03-12',
#   '06:03:05',
#   '+0000',
#   '1498826249934086147',
#   'zhichaoguo8',
#   'ZhiChao Guo',
#   '',
#   '@FoxNews America should help Ukraine, bomb Russia immediately',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/ZhiChaoGuo8/status/1502525569178959874',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'FoxNews', 'name': 'Fox News', 'id': '1367531'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525566532136961',
#   '1502525566532136961',
#   '2022-03-12 06:03:05 UTC',
#   '2022-03-12',
#   '06:03:05',
#   '+0000',
#   '1439999046916075524',
#   'ishantmehta8929',
#   'Ishant Mehta',
#   '',
#   '#BigStory: The impact of Russia-Ukraine war on Indian entertainment industry – Times of\xa0India  https://t.co/FQxK4dto5D',
#   'en',
#   '[]',
#   "['http://ndtvnewsindia.com/bigstory-the-impact-of-russia-ukraine-war-on-indian-entertainment-industry-times-of-india/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['bigstory']",
#   '[]',
#   'https://twitter.com/Ishantmehta8929/status/1502525566532136961',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525561456918541',
#   '1502521069067911170',
#   '2022-03-12 06:03:04 UTC',
#   '2022-03-12',
#   '06:03:04',
#   '+0000',
#   '1470185491643330561',
#   'zyn6coolmint',
#   'judge dredd',
#   '',
#   '@CalumOakes1 @newsmax You act as if Ukraine isn’t just as corrupt as Russia',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/zyn6coolmint/status/1502525561456918541',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'CalumOakes1', 'name': 'Calum Oakes🔻', 'id': '1096633142956441600'}, {'screen_name': 'newsmax', 'name': 'Newsmax', 'id': '20545835'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525559792107523',
#   '1502245504385789960',
#   '2022-03-12 06:03:03 UTC',
#   '2022-03-12',
#   '06:03:03',
#   '+0000',
#   '279400326',
#   'andansetyanto',
#   'McGyver',
#   '',
#   "@BackseatLiverFC @SamVee93 @cdurant92 @SkySportsNews The fact is abramovich doesn't control russia",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/andansetyanto/status/1502525559792107523',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'BackseatLiverFC', 'name': 'D. Davidson', 'id': '940997216143134720'}, {'screen_name': 'SamVee93', 'name': 'Vee', 'id': '1421382332297236480'}, {'screen_name': 'cdurant92', 'name': 'Chris Durant 🏎⚽️🎵', 'id': '1369730893888241665'}, {'screen_name': 'SkySportsNews', 'name': 'Sky Sports News', 'id': '108568373'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525559313678343',
#   '1502525559313678343',
#   '2022-03-12 06:03:03 UTC',
#   '2022-03-12',
#   '06:03:03',
#   '+0000',
#   '2801565724',
#   'ladaroslycky',
#   'Black Trident',
#   '',
#   'So this night and morning most of Ukraine was hiding from air raids. The terrorism is incredible. Extent of bombings unknown, but criminal Russia bombed a frozen food warehouse near Kyiv. This is VERY Ominous and smells like planne… https://t.co/nTTFvXa44p  https://t.co/tiqUoxVKB8',
#   'en',
#   '[]',
#   "['https://lnkd.in/d3RQwQ67', 'https://lnkd.in/dB_zuCja']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/LadaRoslycky/status/1502525559313678343',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525556684095490',
#   '1502343310312153089',
#   '2022-03-12 06:03:02 UTC',
#   '2022-03-12',
#   '06:03:02',
#   '+0000',
#   '4740507613',
#   '_flash_au',
#   'Flash',
#   '',
#   '@BalancedChamp @therecount The only war monger is Putin. If Biden was such a war monger he would have sent troops to Ukraine long loooonnnngggg before Russia thought about going across the borders',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/_Flash_Au/status/1502525556684095490',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'BalancedChamp', 'name': 'Darius of Noxus', 'id': '1548862362'}, {'screen_name': 'therecount', 'name': 'The Recount', 'id': '1087380412089987077'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525556465799171',
#   '1501642645403320330',
#   '2022-03-12 06:03:02 UTC',
#   '2022-03-12',
#   '06:03:02',
#   '+0000',
#   '3016338831',
#   'sirrickowen',
#   'Sir Richard Owen',
#   '',
#   '@martin_westall @Jules_In_Love @FPoShan @rudeamy23 @RussianEmbassy @mod_russia @mfa_russia @RusembUkraine @RusConsKharkov @rusembassynl @RF_OSCE @BBCWorld @guardian @standardnews @Daily_Express Whatever, troll!',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/sirrickowen/status/1502525556465799171',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'martin_westall', 'name': 'Martin Westall', 'id': '1497351107617697797'}, {'screen_name': 'Jules_In_Love', 'name': 'Jules', 'id': '326602747'}, {'screen_name': 'FPoShan', 'name': 'Frannie💙(@🏠) RN ❤️', 'id': '100643234'}, {'screen_name': 'rudeamy23', 'name': 'very rude escalator screamer', 'id': '45601308'}, {'screen_name': 'RussianEmbassy', 'name': 'Russian Embassy, UK', 'id': '114718372'}, {'screen_name': 'mod_russia', 'name': 'Минобороны России', 'id': '2742078001'}, {'screen_name': 'mfa_russia', 'name': 'MFA Russia 🇷🇺', 'id': '255471924'}, {'screen_name': 'RusembUkraine', 'name': 'RusEmbassy Ukraine', 'id': '1256490685'}, {'screen_name': 'RusConsKharkov', 'name': 'RusConsulate-Kharkov', 'id': '3092275275'}, {'screen_name': 'rusembassynl', 'name': 'Russian Embassy in NL🇷🇺🇳🇱', 'id': '3256927757'}, {'screen_name': 'RF_OSCE', 'name': 'Russian Mission OSCE', 'id': '2177016702'}, {'screen_name': 'BBCWorld', 'name': 'BBC News (World)', 'id': '742143'}, {'screen_name': 'guardian', 'name': 'The Guardian', 'id': '87818409'}, {'screen_name': 'standardnews', 'name': 'Evening Standard', 'id': '38142380'}, {'screen_name': 'Daily_Express', 'name': 'Daily Express', 'id': '17895820'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525555102691330',
#   '1502523961371996163',
#   '2022-03-12 06:03:02 UTC',
#   '2022-03-12',
#   '06:03:02',
#   '+0000',
#   '615016320',
#   'losardotony',
#   'cadabra85',
#   '',
#   '@JessicaPerthWA @PrivateHelpOrg God help russia to win😂😂😂',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/losardotony/status/1502525555102691330',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'JessicaPerthWA', 'name': 'Jessica Mason', 'id': '1471706319828643844'}, {'screen_name': 'PrivateHelpOrg', 'name': 'Ukraine 🇺🇦', 'id': '156975764'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525553966043138',
#   '1502525553966043138',
#   '2022-03-12 06:03:02 UTC',
#   '2022-03-12',
#   '06:03:02',
#   '+0000',
#   '522530914',
#   'michaelh992',
#   'Michael A. Horowitz',
#   '',
#   "Threat on #Russia's invasion of #Ukraine - March 12",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['russia', 'ukraine']",
#   '[]',
#   'https://twitter.com/michaelh992/status/1502525553966043138',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525551936151554',
#   '1502525551936151554',
#   '2022-03-12 06:03:01 UTC',
#   '2022-03-12',
#   '06:03:01',
#   '+0000',
#   '1357638497092345856',
#   'mdnazru36122216',
#   'Md.Nazrul Islam',
#   '',
#   '"What is the cost of China\'s friendship with Russia?"   https://t.co/M5XMUSMNS7',
#   'en',
#   '[]',
#   "['https://twitter.com/i/events/1502176325892653056']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/MdNazru36122216/status/1502525551936151554',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525551642550272',
#   '1502525551642550272',
#   '2022-03-12 06:03:01 UTC',
#   '2022-03-12',
#   '06:03:01',
#   '+0000',
#   '861474047678447617',
#   'theasianinduk',
#   'The Asian Independent',
#   '',
#   'Middle East volunteers ready to assist Russia in Ukraine war  https://t.co/YXrvJBKkra via @Asian Independent  https://t.co/lFt5YJchLR',
#   'en',
#   '[]',
#   "['https://theasianindependent.co.uk/middle-east-volunteers-ready-to-assist-russia-in-ukraine-war/']",
#   "['https://pbs.twimg.com/media/FNoLBX1agAANcb0.jpg']",
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/TheAsianInduk/status/1502525551642550272',
#   'False',
#   '',
#   '1',
#   'https://pbs.twimg.com/media/FNoLBX1agAANcb0.jpg',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525551340310535',
#   '1502525551340310535',
#   '2022-03-12 06:03:01 UTC',
#   '2022-03-12',
#   '06:03:01',
#   '+0000',
#   '390070248',
#   'jorgecortell',
#   'Jorge Cortell (He/His/Him) 🔻🌍🌏🌎',
#   '',
#   'Iran nuclear talks "paused" over Russia\'s last-minute sanctions demands -  https://t.co/ZDdocG2qn2',
#   'en',
#   '[]',
#   "['https://www.axios.com/iran-nuclear-deal-talks-russia-e4707776-52d0-47c5-9eac-a3d9b8555d82.html']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/jorgecortell/status/1502525551340310535',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525547326410754',
#   '1502312106863042563',
#   '2022-03-12 06:03:00 UTC',
#   '2022-03-12',
#   '06:03:00',
#   '+0000',
#   '1460506916061384709',
#   'viktormakaren77',
#   'Віктор Макєрман',
#   '',
#   "@jensstoltenberg @RTErdogan Andrei Piontkovsky @apiontkovsky · 11 o'clock Stoltenberg: Our main task is to avoid war with Russia. This is not your job. This is the task of politicians. And your task, asshole, is to win this war, if it does start.  https://t.co/huS9NdkkcZ",
#   'en',
#   "[{'screen_name': 'apiontkovsky', 'name': 'andrei piontkovsky', 'id': '985979834'}]",
#   '[]',
#   "['https://pbs.twimg.com/media/FNoLAuVX0AMpjBf.jpg', 'https://pbs.twimg.com/media/FNoLAucX0AAPWnx.jpg', 'https://pbs.twimg.com/media/FNoLAucXEAA1W8n.jpg', 'https://pbs.twimg.com/media/FNoLAvjXEAA54r6.jpg']",
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/ViktorMakaren77/status/1502525547326410754',
#   'False',
#   '',
#   '1',
#   'https://pbs.twimg.com/media/FNoLAuVX0AMpjBf.jpg',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'jensstoltenberg', 'name': 'Jens Stoltenberg', 'id': '20796069'}, {'screen_name': 'RTErdogan', 'name': 'Recep Tayyip Erdoğan', 'id': '68034431'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525546739118084',
#   '1502525546739118084',
#   '2022-03-12 06:03:00 UTC',
#   '2022-03-12',
#   '06:03:00',
#   '+0000',
#   '107612608',
#   'auntyalias',
#   'auntyalias@gmail.com',
#   '',
#   'Asian Boss - What Do the Chinese Think of Russia? | Street Interview  https://t.co/pbUrRLM8XO via @YouTube',
#   'en',
#   "[{'screen_name': 'youtube', 'name': 'youtube', 'id': '10228272'}]",
#   "['https://youtu.be/vZoxqltgS0Y']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/AuntyAlias/status/1502525546739118084',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525545812140032',
#   '1502431171245977600',
#   '2022-03-12 06:03:00 UTC',
#   '2022-03-12',
#   '06:03:00',
#   '+0000',
#   '274858463',
#   'nancylovesfrank',
#   'Frank Loves Nancy',
#   '',
#   '@McFaul How about NATO proposing to conduct “special operations” in Belarus to stop its aggression towards Ukraine and proposing not to do so, if Russia withdraws from Ukraine in addition to Crimea and Dobass? @WhiteHouse @NATO',
#   'en',
#   "[{'screen_name': 'whitehouse', 'name': 'the white house', 'id': '1323730225067339784'}, {'screen_name': 'nato', 'name': 'nato', 'id': '83795099'}]",
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/nancylovesfrank/status/1502525545812140032',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'McFaul', 'name': 'Michael McFaul', 'id': '454099919'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525544604205058',
#   '1502510695874805762',
#   '2022-03-12 06:03:00 UTC',
#   '2022-03-12',
#   '06:03:00',
#   '+0000',
#   '1306608714498023424',
#   'avvwrites',
#   'Festive Source Merlin',
#   '',
#   '@Benny6Toes @What46HasDone What he says doesn’t matter. He can call Biden getting another cat an act of war. It doesn’t matter what he says. No one is getting frightened by what he says. There is no strategic ambiguity as far as NATO and Russia is concerned. Everyone knows where the lines are.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/avvwrites/status/1502525544604205058',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'Benny6Toes', 'name': 'Ben S', 'id': '260383088'}, {'screen_name': 'What46HasDone', 'name': 'What Biden Has Done 🇺🇸 🇺🇦', 'id': '1352292443652124674'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525544159711232',
#   '1502525544159711232',
#   '2022-03-12 06:02:59 UTC',
#   '2022-03-12',
#   '06:02:59',
#   '+0000',
#   '972452413880741889',
#   'ktnewslive',
#   'ktnewslive',
#   '',
#   'Russia widens social media crackdown by blocking\xa0Instagram  https://t.co/DTO7dNzMUV',
#   'en',
#   '[]',
#   "['https://ktnewslive.com/index.php/2022/03/12/russia-widens-social-media-crackdown-by-blocking-instagram/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/ktnewslive/status/1502525544159711232',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525539017498624',
#   '1502525539017498624',
#   '2022-03-12 06:02:58 UTC',
#   '2022-03-12',
#   '06:02:58',
#   '+0000',
#   '1448339565190713351',
#   'anewsgroup1',
#   'A news Group',
#   '',
#   'Joe Biden Says Troops Moved Along Russia Borders, “Won’t Fight World War\xa03”  https://t.co/C3md1NmleP',
#   'en',
#   '[]',
#   "['https://anewsgroup.com/2022/03/12/joe-biden-says-troops-moved-along-russia-borders-wont-fight-world-war-3/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/AnewsGroup1/status/1502525539017498624',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525538862346240',
#   '1502525538862346240',
#   '2022-03-12 06:02:58 UTC',
#   '2022-03-12',
#   '06:02:58',
#   '+0000',
#   '1023463908986761216',
#   'pavel58492926',
#   'Pavel 🇷🇺 🇮🇱 🇨🇦',
#   '',
#   'Citing Ukraine, Facebook declares some hate speech is OK — RT Russia &amp; Former Soviet Union  https://t.co/qAa42aHn9u',
#   'en',
#   '[]',
#   "['https://www.rt.com/russia/551728-facebook-hate-speech-censorship/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Pavel58492926/status/1502525538862346240',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525532608495616',
#   '1502521069067911170',
#   '2022-03-12 06:02:57 UTC',
#   '2022-03-12',
#   '06:02:57',
#   '+0000',
#   '1502512172521308160',
#   'doodoopoopa',
#   'doodoopoopa',
#   '',
#   '@newsmax Russia is bad. Facebook is ghey. Ukraine is a puppet state of globohomo. So, yahoo...',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/doodoopoopa/status/1502525532608495616',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'newsmax', 'name': 'Newsmax', 'id': '20545835'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525530209492992',
#   '1502458252126302208',
#   '2022-03-12 06:02:56 UTC',
#   '2022-03-12',
#   '06:02:56',
#   '+0000',
#   '1488163484168855555',
#   'kzylberstein',
#   'KAROLYNE ZYLBERSTEIN',
#   '',
#   '@kekstarjelqlord @intifada no dukonnard he prevented them from living in russia .they sent them to the gulags because they did not submit',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/KZylberstein/status/1502525530209492992',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'kekstarjelqlord', 'name': '🇵🇸Gigi🇺🇦Hadid🇰🇿Respecter🇺🇸', 'id': '1495232599920459779'}, {'screen_name': 'intifada', 'name': 'Electronic Intifada', 'id': '6721522'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525528745472001',
#   '1502154852738031627',
#   '2022-03-12 06:02:56 UTC',
#   '2022-03-12',
#   '06:02:56',
#   '+0000',
#   '925102251651121152',
#   'mbwassaby',
#   'Keyser Sőze',
#   '',
#   '@MarketRebels Russia needs to take some lessons from China on how to do business with US companies',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/mbwassaby/status/1502525528745472001',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'MarketRebels', 'name': 'Market Rebellion', 'id': '817007725666242561'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525525570564099',
#   '1502310490491531280',
#   '2022-03-12 06:02:55 UTC',
#   '2022-03-12',
#   '06:02:55',
#   '+0000',
#   '1313348334',
#   'chibwechikwa',
#   'Chikwa ysakar chibwe',
#   '',
#   '@JeanetElisa Not sure these sanctions are helping. Why ? Because the Allies goal is to remove Putin as President. This is a declaration of war. What efforts are being made to achieve peace between the Allies and Russia.peace between Ukrainian &amp; the Allies will not stop the sanctions.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/ChibweChikwa/status/1502525525570564099',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'JeanetElisa', 'name': 'Chosen Ministries', 'id': '958803003628277761'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525523708235780',
#   '1502525523708235780',
#   '2022-03-12 06:02:55 UTC',
#   '2022-03-12',
#   '06:02:55',
#   '+0000',
#   '1470904082089091073',
#   'stopvladdydaddy',
#   'OperationX 🇺🇦 | #StandWithUkraine',
#   '',
#   "Russia VS Ukraine.. It is horrible. I made a discord server (also in bio) to talk about it. Send your videos, images etc. Invite:  https://t.co/Ld7jko0ft3 - Let's show our support for Ukraine! #PrayForUkraine #RussiaUkraine #SaveUkraine #StopPutin #russianinvasion (21054)",
#   'en',
#   '[]',
#   "['https://discord.gg/V27CcPs9Wu']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['prayforukraine', 'russiaukraine', 'saveukraine', 'stopputin', 'russianinvasion']",
#   '[]',
#   'https://twitter.com/StopVladdyDaddy/status/1502525523708235780',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525522336784384',
#   '1502452338732277761',
#   '2022-03-12 06:02:54 UTC',
#   '2022-03-12',
#   '06:02:54',
#   '+0000',
#   '1501781308481150977',
#   '762kalash',
#   'Eskimo Joe',
#   '',
#   '@GalenWorthingt1 @SecBlinken the only thing being done clandestinely was instigating, provoking &amp; financing war with Russia',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/762Kalash/status/1502525522336784384',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'GalenWorthingt1', 'name': 'Galen Worthington', 'id': '1166476236157145089'}, {'screen_name': 'SecBlinken', 'name': 'Secretary Antony Blinken', 'id': '1350150750966603777'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525521111891968',
#   '1499792207661969408',
#   '2022-03-12 06:02:54 UTC',
#   '2022-03-12',
#   '06:02:54',
#   '+0000',
#   '9207352',
#   'mfriedma',
#   'Michael Friedman',
#   '',
#   '@pepsi @MTVPopstar Hey, @pepsi how come you are still in Russia?!  No excuses, no half measures.  100% out now!  You are funding the murder of Ukrainian children.  You are dead to me.  My family will never buy another Pepsi product.  #UkraineWar',
#   'en',
#   "[{'screen_name': 'pepsi', 'name': 'pepsi', 'id': '18139619'}]",
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['ukrainewar']",
#   '[]',
#   'https://twitter.com/mfriedma/status/1502525521111891968',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'pepsi', 'name': 'Pepsi', 'id': '18139619'}, {'screen_name': 'MTVPopstar', 'name': 'Becoming A Popstar', 'id': '1484297167393239042'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525520453505024',
#   '1502525520453505024',
#   '2022-03-12 06:02:54 UTC',
#   '2022-03-12',
#   '06:02:54',
#   '+0000',
#   '880112324987822082',
#   'thechestnutpost',
#   'The Chestnut Post',
#   '',
#   'How likely is Russia to default on its\xa0debt?  https://t.co/DVwePXLxcp',
#   'en',
#   '[]',
#   "['https://www.thechestnutpost.com/news/how-likely-is-russia-to-default-on-its-debt/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/TheChestnutPost/status/1502525520453505024',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525517827919872',
#   '1502341469662855181',
#   '2022-03-12 06:02:53 UTC',
#   '2022-03-12',
#   '06:02:53',
#   '+0000',
#   '139855429',
#   'lichterfeld',
#   'Lichterfeld',
#   '',
#   '@vonderleyen Russia won’t be impressed at all. China is ready &amp; happy to fill all gaps any of these sanctions will cause. China and Russia will bond economically and build a military alliance. Any future conflict will be far worse then it could be today. #NoFlyZoneUA #EU #StopRussia',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['noflyzoneua', 'eu', 'stoprussia']",
#   '[]',
#   'https://twitter.com/Lichterfeld/status/1502525517827919872',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'vonderleyen', 'name': 'Ursula von der Leyen', 'id': '1146329871418843136'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525515910971395',
#   '1502525515910971395',
#   '2022-03-12 06:02:53 UTC',
#   '2022-03-12',
#   '06:02:53',
#   '+0000',
#   '1115560567',
#   'marionrmorrison',
#   'John Wayne',
#   '',
#   'German Bank friendly with Russia. How shocking.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/MarionRMorrison/status/1502525515910971395',
#   'False',
#   'https://twitter.com/Billbrowder/status/1502400814782062600',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525514912866305',
#   '1502525514912866305',
#   '2022-03-12 06:02:52 UTC',
#   '2022-03-12',
#   '06:02:52',
#   '+0000',
#   '2784003177',
#   'laciuraraffaele',
#   'Raffaele La Ciura',
#   '',
#   "Russia squeezes Kyiv as 'unimaginable' tragedy looms in Ukraine  https://t.co/e4DwF0Gj6F",
#   'et',
#   '[]',
#   "['https://www.euractiv.com/section/global-europe/news/russia-squeezes-kyiv-as-unimaginable-tragedy-looms-in-ukraine/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/LaCiuraRaffaele/status/1502525514912866305',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525513918783488',
#   '1502525513918783488',
#   '2022-03-12 06:02:52 UTC',
#   '2022-03-12',
#   '06:02:52',
#   '+0000',
#   '1255579440295403520',
#   '3seaseurope',
#   '3 Seas Europe',
#   '',
#   'Number of accepted Ukrainian refugees:  Poland - 1 524 903 Hungary - 225 046 Slovakia - 176 092 Moldova - 104 929 Romania - 84 671 Other European countries - 282 497  Russia - 105 897 Belarus - 858  Total - 2504893 people  #Russia',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['russia']",
#   '[]',
#   'https://twitter.com/3SeasEurope/status/1502525513918783488',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525513679527936',
#   '1502525513679527936',
#   '2022-03-12 06:02:52 UTC',
#   '2022-03-12',
#   '06:02:52',
#   '+0000',
#   '1179012423874777094',
#   'nandkis09458351',
#   'nand kishor verma',
#   '',
#   'Russia Ukraine News: जेलेंस्की ने कहा- रूस ISIS के आतंकियों की तरह कर रहा\xa0काम  https://t.co/O6kHesApr3',
#   'hi',
#   '[]',
#   "['http://hindinews.deshinewsprime.com/?p=195363']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/nandkis09458351/status/1502525513679527936',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525511104348160',
#   '1502493193992036356',
#   '2022-03-12 06:02:52 UTC',
#   '2022-03-12',
#   '06:02:52',
#   '+0000',
#   '318400350',
#   'rabtsevichs',
#   'sergei rabtsevich',
#   '',
#   '@kuratedao @usa @kuratedao @Russia LFG! 🚀🚀🚀🚀',
#   'und',
#   "[{'screen_name': 'russia', 'name': 'russia 🇷🇺', 'id': '2874959663'}]",
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/RabtsevichS/status/1502525511104348160',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'kuratedao', 'name': 'KurateDAO', 'id': '1488066112147406849'}, {'screen_name': 'usa', 'name': 'USA', 'id': '188021635'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525507589775361',
#   '1502525507589775361',
#   '2022-03-12 06:02:51 UTC',
#   '2022-03-12',
#   '06:02:51',
#   '+0000',
#   '430229123',
#   'jita65',
#   'Jita Sharman',
#   '',
#   "This is so tragic #LRT. Did people in Ukraine fell for the trap created by the corrupt Politicians.. US didn't want to fight Russia, they wanted Ukrainians to do that. Who benefits ... Oil &amp; gas Companies &amp; weapon manufactures? So much evil going round.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['lrt']",
#   '[]',
#   'https://twitter.com/jita65/status/1502525507589775361',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525504619888641',
#   '1502525504619888641',
#   '2022-03-12 06:02:50 UTC',
#   '2022-03-12',
#   '06:02:50',
#   '+0000',
#   '1260824667868114944',
#   'ibctamilnadu',
#   'IBC Tamilnadu',
#   '',
#   '"ரஷ்யாவை எதிர்த்து போரிடும் திட்டம் இல்லை"- அமெரிக்கா அதிபர் ஜோ பைடன் | Joe Biden | Russia | IBC VIDEO LINK~ https://t.co/G4kHbDWIl4 #JoeBiden #JeoBidenTwitter #Russia #IBCTamilnadu',
#   'ta',
#   '[]',
#   "['https://youtu.be/OhC5lftkcSI']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   "['joebiden', 'jeobidentwitter', 'russia', 'ibctamilnadu']",
#   '[]',
#   'https://twitter.com/IbcTamilnadu/status/1502525504619888641',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525504179433475',
#   '1502525504179433475',
#   '2022-03-12 06:02:50 UTC',
#   '2022-03-12',
#   '06:02:50',
#   '+0000',
#   '1157035813323956224',
#   'filip04354978',
#   'Filip Jehoshaphat O’Larry',
#   '',
#   'Fertility of the land: a comparison Sweden vs Russia  Even though Sweden had a record breaking harvest at 6 million tons Russia’s harvest is about 20x more at 120 million tons. Ukraine’s harvest is standing at 80 million tons which could feed more than 100 million ppl.  https://t.co/ELBr1fJDL7',
#   'en',
#   '[]',
#   '[]',
#   "['https://pbs.twimg.com/media/FNoK-uvVEAETB0m.jpg', 'https://pbs.twimg.com/media/FNoK-vjVQAArc0P.jpg']",
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Filip04354978/status/1502525504179433475',
#   'False',
#   '',
#   '1',
#   'https://pbs.twimg.com/media/FNoK-uvVEAETB0m.jpg',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525503655325697',
#   '1502525503655325697',
#   '2022-03-12 06:02:50 UTC',
#   '2022-03-12',
#   '06:02:50',
#   '+0000',
#   '1433260182147108864',
#   'lordweb1',
#   'lord web',
#   '',
#   'russian federation – Why is China complying with sanctions against Russia?\xa0Answer  https://t.co/3XsUavTyVc',
#   'en',
#   '[]',
#   "['https://wlord.org/russian-federation-why-is-china-complying-with-sanctions-against-russia-answer/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/lordweb1/status/1502525503655325697',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525503596822530',
#   '1502524681253179393',
#   '2022-03-12 06:02:50 UTC',
#   '2022-03-12',
#   '06:02:50',
#   '+0000',
#   '2999187584',
#   'ketameans',
#   'lach',
#   '',
#   'liberal media at first glorifying neo-nazi militias and now dabbling in actual holocaust denial to own russia... yeah ok',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/ketameans/status/1502525503596822530',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525502128812034',
#   '1502525502128812034',
#   '2022-03-12 06:02:49 UTC',
#   '2022-03-12',
#   '06:02:49',
#   '+0000',
#   '90840225',
#   'zz1688',
#   'Rosalind Karpin',
#   '',
#   'Explaining the Faith - Ukraine, Russia, Fatima: What Is Heaven Telling Us?  https://t.co/fuGjDtqwfz via @YouTube',
#   'en',
#   "[{'screen_name': 'youtube', 'name': 'youtube', 'id': '10228272'}]",
#   "['https://youtu.be/wMi6iKhgdpI']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/zz1688/status/1502525502128812034',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525501407117313',
#   '1502459450355068930',
#   '2022-03-12 06:02:49 UTC',
#   '2022-03-12',
#   '06:02:49',
#   '+0000',
#   '48977854',
#   'matwill',
#   'Mathew Williams 🇦🇺🇱🇺⛵',
#   '',
#   '@TechInvest20 @AdamKinzinger You are lucky trump is not in power, he would probably send troops to aid russia',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/MatWill/status/1502525501407117313',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'TechInvest20', 'name': 'Stand with Ukrain 🇺🇦🇺🇸❤️', 'id': '1466205543312277504'}, {'screen_name': 'AdamKinzinger', 'name': 'Adam Kinzinger', 'id': '18004222'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525497757954051',
#   '1502408403573886978',
#   '2022-03-12 06:02:48 UTC',
#   '2022-03-12',
#   '06:02:48',
#   '+0000',
#   '1498736552549109761',
#   'liv2fish846',
#   'Myles Holenstein',
#   '',
#   "@OliveSaurusRex @TrueElimination @mrscparks6 @jjhorgan I didnt think you'd articulate an intelligent answer. So I'll help you out...nothing changed. Covid is still here. Its everywhere...always will be. Only difference now is the media quit talking about it and turned your attention to Russia. Thats it. You're a gullible lemming",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/liv2fish846/status/1502525497757954051',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'OliveSaurusRex', 'name': 'OliveSaurusRex 🌻', 'id': '4699023134'}, {'screen_name': 'TrueElimination', 'name': 'Elimination', 'id': '1357198764360966144'}, {'screen_name': 'mrscparks6', 'name': 'Ceejay', 'id': '555650921'}, {'screen_name': 'jjhorgan', 'name': 'John Horgan', 'id': '232427887'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525497728638978',
#   '1502525497728638978',
#   '2022-03-12 06:02:48 UTC',
#   '2022-03-12',
#   '06:02:48',
#   '+0000',
#   '1455041560165240834',
#   'eugeneeridul',
#   'Eugenio Idul',
#   '',
#   'Philippines is making a show of housing its airforce capabilities in one airfield which is wrong because any opponent may strike it and the whole nation will collapse like what happened to ukrain airbase in a war with russia. It must be scalated to hide it from any enemies eyes.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Eugeneeridul/status/1502525497728638978',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502525497200238593',
#   '1502373294288347136',
#   '2022-03-12 06:02:48 UTC',
#   '2022-03-12',
#   '06:02:48',
#   '+0000',
#   '763299434',
#   'torchbearerlive',
#   'The Torch Bearer',
#   '',
#   '@realsurgesolar @ChuckCallesto It was always public.  Now just obfuscation.   It’s gaslighting 101.  Yes American runs and funds 200+ biolabs globally. Some are tax payer funded offensive weapons labs.  China and Russia are correct',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/torchbearerLIVE/status/1502525497200238593',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'realsurgesolar', 'name': 'Surge Solar', 'id': '959993543627386880'}, {'screen_name': 'ChuckCallesto', 'name': 'Chuck Callesto', 'id': '4765364386'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502525496965312514',
#   '1502474524398301186',
#   '2022-03-12 06:02:48 UTC',
#   '2022-03-12',
#   '06:02:48',
#   '+0000',
#   '1360404779130712064',
#   'freedomfrmg',
#   'FreedomfrmGOP',
#   '',
#   '@donwinslow Most of the Putin loving republicans have bank account in Russia with Russian bank credit cards',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/FreedomfrmG/status/1502525496965312514',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'donwinslow', 'name': 'Don Winslow', 'id': '255812611'}]",
#   '',
#   '',
#   '',
#   ''],
# ...
#   '05:57:00',
#   '+0000',
#   '1386306519801675781',
#   'codecanyon3',
#   'Avitoa.com - News',
#   '',
#   'Russia-Ukraine war update: what we know on day 17 of the Russian invasion |\xa0Ukraine  https://t.co/m2qYDS0wHI',
#   'en',
#   '[]',
#   "['https://www.avitoa.com/russia-ukraine-war-update-what-we-know-on-day-17-of-the-russian-invasion-ukraine/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Codecanyon3/status/1502524035808305153',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524035741196288',
#   '1502433007721799680',
#   '2022-03-12 05:57:00 UTC',
#   '2022-03-12',
#   '05:57:00',
#   '+0000',
#   '1482890862',
#   'whitzes',
#   'Sean',
#   '',
#   "@ravelesm @piperscreekway @Commie_Angel @SusanSarandon @TheOliverStone Oh, there is plenty, plenty of evidence! If Russia Today runs clips of Tucker in their Russian studio after closing all independent media.  It's pretty fair assessment to say Tucker is spreading a message that Putin wants heard. It's not a hard leap",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '1',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/whitzes/status/1502524035741196288',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'ravelesm', 'name': '🍀Michael Raveles🕊🏴🚩🍀🌹🌵🌹🌵🌹🌵', 'id': '4286776944'}, {'screen_name': 'piperscreekway', 'name': 'Pipers Creek', 'id': '1420962115544752137'}, {'screen_name': 'Commie_Angel', 'name': '☭Commie☭Angel☭♿🏳️\\u200d🌈🇵🇸🇨🇺🇻🇪🇰🇵🇨🇳🇮🇷', 'id': '1219064153551163394'}, {'screen_name': 'SusanSarandon', 'name': 'Susan Sarandon', 'id': '618300542'}, {'screen_name': 'TheOliverStone', 'name': 'Oliver Stone', 'id': '538021652'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524034545770500',
#   '1502061361383321625',
#   '2022-03-12 05:57:00 UTC',
#   '2022-03-12',
#   '05:57:00',
#   '+0000',
#   '41597531',
#   'jammie04038',
#   'Jan Williams',
#   '',
#   '@therobyntodd @AndrewDesiderio @hughhewitt Are you willing to send your son off to war? Russia is just waiting for us to make a move and we are in something we will never get out of until many American are killed! It’s not our war!',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/jammie04038/status/1502524034545770500',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'therobyntodd', 'name': 'Robyn Todd', 'id': '260858013'}, {'screen_name': 'AndrewDesiderio', 'name': 'Andrew Desiderio', 'id': '427630477'}, {'screen_name': 'hughhewitt', 'name': 'Hugh Hewitt', 'id': '15075999'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524033736318979',
#   '1502524033736318979',
#   '2022-03-12 05:56:59 UTC',
#   '2022-03-12',
#   '05:56:59',
#   '+0000',
#   '1431886953998258177',
#   'thegoogle93',
#   'The Google',
#   '',
#   'Ukraine Crisis: On the 17th day of the war, Russia became a fierce aggressor, Biden said – World War I is one step ahead. Ukraine Crisis Day 17 Russian strikes raise Biden’s warning Putin NATO Zelensky air strikes\xa0Kyiv  https://t.co/Y9KbyTlD35',
#   'en',
#   '[]',
#   "['https://thegooglenews.in/2022/03/12/ukraine-crisis-on-the-17th-day-of-the-war-russia-became-a-fierce-aggressor-biden-said-world-war-i-is-one-step-ahead-ukraine-crisis-day-17-russian-strikes-raise-bidens-warning-putin-nato-zelens/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/thegoogle93/status/1502524033736318979',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524033719574531',
#   '1501863004270440452',
#   '2022-03-12 05:56:59 UTC',
#   '2022-03-12',
#   '05:56:59',
#   '+0000',
#   '3313717612',
#   'emperorcheddah',
#   'Emperor Raphael ⭐️⭐️',
#   '',
#   '@RosaCatherineK @Curtis_H_94 @cammy3000 @arsenal_25 @jamiewiIkinson His steel company also supplies to UK, so he must be responsible if UK decides to go to war tomorrow. UK still buys gas from Russia so they are as well funding the war yea??',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/emperorcheddah/status/1502524033719574531',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'RosaCatherineK', 'name': 'Rosa', 'id': '1260531512'}, {'screen_name': 'Curtis_H_94', 'name': 'Curtis', 'id': '1457186129678057473'}, {'screen_name': 'cammy3000', 'name': 'Cammy3000', 'id': '31705556'}, {'screen_name': 'arsenal_25', 'name': 'unique _ cutie', 'id': '152237175'}, {'screen_name': 'jamiewiIkinson', 'name': 'Jamie Wilkinson', 'id': '1256211569496686592'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524029827092481',
#   '1502433817465864198',
#   '2022-03-12 05:56:58 UTC',
#   '2022-03-12',
#   '05:56:58',
#   '+0000',
#   '1419760565572956161',
#   'writtenrp',
#   'MMO RP',
#   '',
#   "@words_by_jess @anartam @prayer4ukraine @nexta_tv She could be using her last posts to spread awareness about Ukraine.  But she's crying about Instagram being her soul.  I understand financial distress, but the power of an influencer is exactly what Russia would need to start protesting in mass.  The definition of self-centered.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '1',
#   '[]',
#   '[]',
#   'https://twitter.com/writtenRP/status/1502524029827092481',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'words_by_jess', 'name': 'Hope is the thing with feathers', 'id': '331747793'}, {'screen_name': 'anartam', 'name': 'Ana Rosa Amorim', 'id': '19826665'}, {'screen_name': 'prayer4ukraine', 'name': 'PrayForUkraine', 'id': '1267214581044334596'}, {'screen_name': 'nexta_tv', 'name': 'NEXTA', 'id': '1891490382'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524028367474690',
#   '1502406298423365633',
#   '2022-03-12 05:56:58 UTC',
#   '2022-03-12',
#   '05:56:58',
#   '+0000',
#   '1405008827754319877',
#   'mydogsnores00',
#   'My Dog Snores',
#   '',
#   '@TaraBull808 Russia, Russia, Russia!  https://t.co/spmYKjLW1Y',
#   'fi',
#   '[]',
#   '[]',
#   "['https://pbs.twimg.com/media/FNoJpBJUYAATco8.jpg']",
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Mydogsnores00/status/1502524028367474690',
#   'False',
#   '',
#   '1',
#   'https://pbs.twimg.com/media/FNoJpBJUYAATco8.jpg',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'TaraBull808', 'name': 'TaraBull\\uea00', 'id': '1374968033265864706'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524027746889729',
#   '1502387384914100224',
#   '2022-03-12 05:56:58 UTC',
#   '2022-03-12',
#   '05:56:58',
#   '+0000',
#   '1494322001011372053',
#   'titus35095345',
#   'Titus',
#   '',
#   '@tedcruz Biden slapped sanctions on domestic oil companies on day one and by day 4 lifted sanctions on Russia and flooding our oil markets with Putins oil.  Billions of US dollars funding his invasion. Congrats Joke Biden!',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Titus35095345/status/1502524027746889729',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'tedcruz', 'name': 'Ted Cruz', 'id': '23022687'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524026807275520',
#   '1502342468603367430',
#   '2022-03-12 05:56:58 UTC',
#   '2022-03-12',
#   '05:56:58',
#   '+0000',
#   '1480193589690966019',
#   'paulose2541975',
#   'Paulo S',
#   '',
#   '@kamgodoyi @BongMelz Zelenski is a power hungry politician and has little consideration for his own people. Post 2014 and now against Russia. Just as much blood on his hands.',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/PauloSe2541975/status/1502524026807275520',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'kamgodoyi', 'name': 'Eric Swag King🇿🇦🇺🇸', 'id': '1332610290677067776'}, {'screen_name': 'BongMelz', 'name': 'I stand with the marginalized', 'id': '2223330125'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524026438180867',
#   '1502257805088153607',
#   '2022-03-12 05:56:58 UTC',
#   '2022-03-12',
#   '05:56:58',
#   '+0000',
#   '1194478472695091200',
#   'mfalmejuhatz',
#   'Mzee Baba',
#   '',
#   "@Zawszeztoba @gyraneg @Labella_Mafia95 Naa! Em black men from Russia..we Don't cheat..tunafanyaga mazoez ya kikojoleo..😂",
#   'in',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/MfalmeJuhaTz/status/1502524026438180867',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'Zawszeztoba', 'name': 'Franek Kazuwaski 🇹🇿🇵🇱🇬🇧', 'id': '1367904180342562820'}, {'screen_name': 'gyraneg', 'name': 'lissa lima', 'id': '1454456167728619526'}, {'screen_name': 'Labella_Mafia95', 'name': '𝐋𝐚𝐛𝐞𝐥𝐥𝐚 𝐌𝐚𝐟𝐢𝐚', 'id': '1396347896765820931'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524024198352896',
#   '1502524024198352896',
#   '2022-03-12 05:56:57 UTC',
#   '2022-03-12',
#   '05:56:57',
#   '+0000',
#   '1456228393234493446',
#   'reddysalina',
#   'Salina Reddy',
#   '',
#   "After #Meeting with #EU #Leaders in #France on Friday, #Spain’s #primeminister insisted that he will do #everything in his #power to change the European Union's #energy #Policy away from dependence on #Russia.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '1',
#   '0',
#   '0',
#   "['meeting', 'eu', 'leaders', 'france', 'spain', 'primeminister', 'everything', 'power', 'energy', 'policy', 'russia']",
#   '[]',
#   'https://twitter.com/ReddySalina/status/1502524024198352896',
#   'False',
#   'https://twitter.com/anadoluagency/status/1502427901995761670',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524023216951297',
#   '1502474753566773256',
#   '2022-03-12 05:56:57 UTC',
#   '2022-03-12',
#   '05:56:57',
#   '+0000',
#   '1350689982680363008',
#   'gabrielbragavl',
#   'Gabriel Braga',
#   '',
#   '@williamwfilene @bsabadini @PallottaPedro O papo dos mísseis é mais balela, estados bálticos estão do lado da Rússia e são da Otan e não possuem qualquer míssil, se os EUA quisesse era so cercar a Rússia com submarinos equipados com SLBM, ou seja, n passa de balela russa sem qualquer sentido.',
#   'pt',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/GabrielBragaVL/status/1502524023216951297',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'williamwfilene', 'name': 'william claudio', 'id': '2901167380'}, {'screen_name': 'bsabadini', 'name': 'Bruno Sabadini🇺🇦', 'id': '94793505'}, {'screen_name': 'PallottaPedro', 'name': 'Pedro Pallotta', 'id': '2909304994'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524023154085889',
#   '1502513107570155521',
#   '2022-03-12 05:56:57 UTC',
#   '2022-03-12',
#   '05:56:57',
#   '+0000',
#   '244331492',
#   'dbglisson',
#   'Debbie Deplorable🇺🇸❤🇺🇸',
#   '',
#   "@AstridNJohnson No one said that but understand we don't need to be in a war with Russia. But no one talks about Ukraine being so corrupt just Russia. We can't fight wars for everyone. My son doesn't need to fight a war Biden practically started.",
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/dbglisson/status/1502524023154085889',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'AstridNJohnson', 'name': 'Astrid Johnson', 'id': '604295802'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524020654510080',
#   '1502524020654510080',
#   '2022-03-12 05:56:56 UTC',
#   '2022-03-12',
#   '05:56:56',
#   '+0000',
#   '1348466047855202305',
#   'dmitri_golovin',
#   'Dmitri Golovin',
#   '',
#   'It’s not what you do that counts.  It’s what the media says about what you do.  #Ukraine️ #Russia #RussiaUkraine #UkraineWar #FakeNews  https://t.co/DLlY9tqn4Z',
#   'en',
#   '[]',
#   '[]',
#   "['https://pbs.twimg.com/media/FNoJoVyaAAEtbu4.jpg']",
#   '0',
#   '1',
#   '1',
#   "['ukraine️', 'russia', 'russiaukraine', 'ukrainewar', 'fakenews']",
#   '[]',
#   'https://twitter.com/dmitri_golovin/status/1502524020654510080',
#   'False',
#   '',
#   '1',
#   'https://pbs.twimg.com/media/FNoJoVyaAAEtbu4.jpg',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524012861173761',
#   '1502524012861173761',
#   '2022-03-12 05:56:54 UTC',
#   '2022-03-12',
#   '05:56:54',
#   '+0000',
#   '994242738676789249',
#   'worldnews_guru',
#   'World News Guru',
#   '',
#   'Russia-Ukraine war: A warm hug meant that war had\xa0begun  https://t.co/NYHD8nE35p',
#   'en',
#   '[]',
#   "['https://worldnewsguru.us/web-stories/russia-ukraine-war-a-warm-hug-meant-that-war-had-begun-5/']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/worldnews_guru/status/1502524012861173761',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524011208708097',
#   '1502397889833746433',
#   '2022-03-12 05:56:54 UTC',
#   '2022-03-12',
#   '05:56:54',
#   '+0000',
#   '1406045798559891460',
#   'potters96601860',
#   'Potters',
#   '',
#   '@Saif349855841 @KittyBlowsGlass @POTUS u realize russia has been killing gays and other minioritirs for years',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/Potters96601860/status/1502524011208708097',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'Saif349855841', 'name': 'Saif', 'id': '1468178794804649988'}, {'screen_name': 'KittyBlowsGlass', 'name': 'Kitty Mathieson', 'id': '24540282'}, {'screen_name': 'POTUS', 'name': 'President Biden', 'id': '1349149096909668363'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524010688483329',
#   '1502524010688483329',
#   '2022-03-12 05:56:54 UTC',
#   '2022-03-12',
#   '05:56:54',
#   '+0000',
#   '2326523312',
#   'noblejtnalger',
#   'Jack Noble',
#   '',
#   '@NikkiHaley President Biden and all of Allies will a strong response to any chemical attacks! Unlike you and Trump did when Syria and Russia did! Listen "B.... B...." you, Pompeo and Trump caused this problem! I predict these 5 years ago and it has come true!',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/NobleJtnalger/status/1502524010688483329',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524008859795461',
#   '1502524008859795461',
#   '2022-03-12 05:56:53 UTC',
#   '2022-03-12',
#   '05:56:53',
#   '+0000',
#   '1386756360428167168',
#   'oneshoup',
#   'NumberOneShoupFan',
#   '',
#   "The mayor of Mykolaiv (a city in S UKR which is on the frontlines now) is Vitaliy Kim. His dad was a Koryo-Saram (고려사람, Корьо-сарам), Koreans who were relocated by Stalin from Russia's far East.  https://t.co/go6fwd2Qc4",
#   'und',
#   '[]',
#   "['https://en.wikipedia.org/wiki/Vitaliy_Kim']",
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/OneShoup/status/1502524008859795461',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '[]',
#   '',
#   '',
#   '',
#   ''],
#  ['1502524007996071937',
#   '1502462453929902081',
#   '2022-03-12 05:56:53 UTC',
#   '2022-03-12',
#   '05:56:53',
#   '+0000',
#   '1483158786806542337',
#   'astartesibel',
#   'Sibel.Astarte ❤️Z❤️',
#   '',
#   '@elenaevdokimov7 It’s ok, most of us who want to give Russia a chance already did. We already awaken, can’t hoodwink us again 😏I just miss being able to hear the meeting conferences in the kremlin but will find other sources to watch them. 👍',
#   'en',
#   '[]',
#   '[]',
#   '[]',
#   '0',
#   '0',
#   '0',
#   '[]',
#   '[]',
#   'https://twitter.com/AstarteSibel/status/1502524007996071937',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'elenaevdokimov7', 'name': 'Elena Evdokimova', 'id': '3397244179'}]",
#   '',
#   '',
#   '',
#   ''],
#  ['1502524007723134979',
#   '1502493193992036356',
#   '2022-03-12 05:56:53 UTC',
#   '2022-03-12',
#   '05:56:53',
#   '+0000',
#   '1463673919169351685',
#   'rramzezz',
#   'Robin Gold',
#   '',
#   '@kuratedao @usa @kuratedao @Russia',
#   'und',
#   "[{'screen_name': 'russia', 'name': 'russia 🇷🇺', 'id': '2874959663'}]",
#   '[]',
#   '[]',
#   '1',
#   '0',
#   '1',
#   '[]',
#   '[]',
#   'https://twitter.com/RRamzezz/status/1502524007723134979',
#   'False',
#   '',
#   '0',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   '',
#   "[{'screen_name': 'kuratedao', 'name': 'KurateDAO', 'id': '1488066112147406849'}, {'screen_name': 'usa', 'name': 'USA', 'id': '188021635'}]",
#   '',
#   '',
#   '',
#   ''],
#  ...]

# %%
file.close()
