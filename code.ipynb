# %%
import tweepy
import csv
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np 
import re
import matplotlib.pyplot as plt
import sklearn
plt.style.use('fivethirtyeight')

# %%
faketweets = pd.read_csv(r'C:\Keziah\Ukraine Tweets\filename.csv', encoding="utf8")
faketweets
# Out:
#                         id      conversation_id               created_at  \
# 0      1502525606596169728  1502257690394963971  2022-03-12 06:03:14 UTC
# 1      1502525604536541191  1502525604536541191  2022-03-12 06:03:14 UTC
# 2      1502525600917082112  1502525600917082112  2022-03-12 06:03:13 UTC
# 3      1502525598282960898  1502214676561776642  2022-03-12 06:03:12 UTC
# 4      1502525596898836480  1500436651264380931  2022-03-12 06:03:12 UTC
# ...                    ...                  ...                      ...
# 10001  1502509750776442882  1502509750776442882  2022-03-12 05:00:14 UTC
# 10002  1502509748666699779  1502475873152376836  2022-03-12 05:00:14 UTC
# 10003  1502509748440244225  1502477543877877764  2022-03-12 05:00:13 UTC
# 10004  1502509747626516481  1502509747626516481  2022-03-12 05:00:13 UTC
# 10005  1502509747483852803  1502508568314093569  2022-03-12 05:00:13 UTC
#
#              date      time  timezone              user_id         username  \
# 0      2022-03-12  06:03:14         0             20198797         redcelia
# 1      2022-03-12  06:03:14         0            227535569          eee_eff
# 2      2022-03-12  06:03:13         0             84313171      mistify_007
# 3      2022-03-12  06:03:12         0   989861790245900289  reallivinghuman
# 4      2022-03-12  06:03:12         0  1164944946392109056           rpcsas
# ...           ...       ...       ...                  ...              ...
# 10001  2022-03-12  05:00:14         0           3985609575        magpieuae
# 10002  2022-03-12  05:00:14         0  1502371278442967040        30kftview
# 10003  2022-03-12  05:00:13         0             10487222          claes69
# 10004  2022-03-12  05:00:13         0           1181472344    businesstimes
# 10005  2022-03-12  05:00:13         0           2195557854       malianking
#
#                                           name place  ... geo source  \
# 0        Johnson Out🇺🇦 🇪🇺🇮🇹🇦🇫💙😷 #NeverVoteTory   NaN  ... NaN    NaN
# 1      Wearing Masks still saves lives 🇺🇦🇲🇨🏥🌹🌹   NaN  ... NaN    NaN
# 2                                    Brian🤸‍♀️   NaN  ... NaN    NaN
# 3                                        Basha   NaN  ... NaN    NaN
# 4                                       RonJon   NaN  ... NaN    NaN
# ...                                        ...   ...  ...  ..    ...
# 10001                                   magpie   NaN  ... NaN    NaN
# 10002                     Michael J. Hueppeler   NaN  ... NaN    NaN
# 10003    Tom Mater 🌻Русский корабль, иди нахуй   NaN  ... NaN    NaN
# 10004                       The Business Times   NaN  ... NaN    NaN
# 10005                               MalianKing   NaN  ... NaN    NaN
#
#       user_rt_id user_rt retweet_id  \
# 0            NaN     NaN        NaN
# 1            NaN     NaN        NaN
# 2            NaN     NaN        NaN
# 3            NaN     NaN        NaN
# 4            NaN     NaN        NaN
# ...          ...     ...        ...
# 10001        NaN     NaN        NaN
# 10002        NaN     NaN        NaN
# 10003        NaN     NaN        NaN
# 10004        NaN     NaN        NaN
# 10005        NaN     NaN        NaN
#
#                                                 reply_to  retweet_date  \
# 0      [{'screen_name': 'RussianEmbassy', 'name': 'Ru...           NaN
# 1                                                     []           NaN
# 2                                                     []           NaN
# 3      [{'screen_name': 'RussianEmbassy', 'name': 'Ru...           NaN
# 4      [{'screen_name': 'IsraeliPM', 'name': 'Prime M...           NaN
# ...                                                  ...           ...
# 10001                                                 []           NaN
# 10002  [{'screen_name': 'SantiagoAuFund', 'name': 'Sa...           NaN
# 10003  [{'screen_name': 'IWasTheGoodGuy', 'name': 'Ga...           NaN
# 10004                                                 []           NaN
# 10005  [{'screen_name': 'Independent', 'name': 'The I...           NaN
#
#        translate trans_src trans_dest
# 0            NaN       NaN        NaN
# 1            NaN       NaN        NaN
# 2            NaN       NaN        NaN
# 3            NaN       NaN        NaN
# 4            NaN       NaN        NaN
# ...          ...       ...        ...
# 10001        NaN       NaN        NaN
# 10002        NaN       NaN        NaN
# 10003        NaN       NaN        NaN
# 10004        NaN       NaN        NaN
# 10005        NaN       NaN        NaN
#
# [10006 rows x 36 columns]

# %%
# Out:
#   File "C:\Users\boomp\AppData\Local\Temp\ipykernel_22216\3320101569.py", line 1
#     faketweets.C:\Keziah\Ukraine Tweets\filename
#                                                 ^
# SyntaxError: unexpected character after line continuation character
